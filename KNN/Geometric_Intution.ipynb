# %%
                #---------KNN---------#
# K-nearest neighbors algorithm (KNN)is a supervised learning algorithmm use in regression and classification
# KNN finds the K nearest neighbors and makes a decision based on them.

# When a new data point needs to be classified or predicted:
    # The algorithm locates it within the space
    # Measures its distance to all existing data points using a distance metric such as Euclidean distance
    # It then identifies the K closest points, known as the “nearest neighbors.
    # At last perform majority count 
    # Pick the class with the highest count (majority)
    # Assign that class to the new point

# As KNN distance based algorithm perform scaling before training

# %%
# KNN is a non-parametric, instance-based learning algorithm.
# Rather than learning a model from the training data, K-NN memorizes the data

# %%
# Key Steps in K-NN
# Select K: Define the number of neighbors, denoted by the hyperparameter K.
# Compute distance: Typically, Euclidean or Manhattan distance is used to identify the nearest data points.
# Majority vote: For classification, the most common class among the K neighbors is predicted.
# For regression, the average of the neighbors' values is calculated.

# %%
# How to select K value?

    # Rule of Thumb:
        # A common starting point: K≈ root over (N)
        # where N = number of training samples
        # If N=100, then K≈10

    # Use Cross-Validation (Best Method)
        # Try multiple K values and pick the one with highest accuracy.

    # Avoid even K (for classification)

# Very small K	Overfitting (too noisy)
# Medium K	Balanced (best choice)
# Very large K	Underfitting (too smooth)
# If the data has lots of noise or outliers, using a larger k can make the predictions more stable.

# %%
# Decision Boundary (Decision Surface)
    # It is use to understand the performance of classification Algorithm (KNN, SVM, LR, DT). 
    # For binary classification it devide the space into two region.
    # Decision surface = Create regions where KNN predicts different classes

# %%
# Overfitting and Underfitting in KNN

# Overfitting
    # What happens?
    # The model learns the training data too perfectly, including noise and outliers.

    # When does it occur?
    # Very small K
    # The model relies on very few neighbors
    # Even noisy points strongly influence predictions

# Undefitting:
    # The model is too simple and fails to capture patterns in the data.
    # Very large K
    # Too many neighbors are considered

# %%
# Limitations: 
# KNN is called a lazy learning algorithm because it does not learn a model during training
# It simply stores the data and delays all computation until prediction time
# It does not work without any query. 
    # Not suitable for large dataset
    # Not suitable for high dimension data
    # In high dim distance not reliable but KNN totaly distance base
    # KNN not work well with outliers
    # Not work with non-homogenous scaling data
    # Imbalanced dataset
    # Sensitive to irrelevant features
    # Memory Dependent

# %%
# Advantages:
# No need to train as it just stores the data and uses it during prediction.
#  Easy to understand and implement.
# Only needs to set the number of neighbors (k) and a distance method.
# Works for both classification and regression problems.

# %%
# Regression problem in KNN
# KNN Regression is machine learning method used to predict continuous values. 
# Example: Prediction of house price

# How It Works (Step-by-Step)
# 1. Choose K
    # Select the best value of K
# 2. Measure Distance
    # Calculate distance between the new point and all existing points (Euclidean or Manhattan).
# 3. Find Nearest Neighbors
    # Select the K closest data points.
# Take A verage
    # Compute the average of their target values.

# Example:
# knn_regressor = KNeighborsRegressor(n_neighbors=5, weights='uniform')
# weights parameter controls how much influence each neighbor has on the prediction.
# Uniform means All 5 neighbors contribute equally to the prediction.
# Here, prediction will be simple average
# Weight='distance' means Closer neighbors have more influence than farther ones.
# Here, prediction will be weighted average

# %%
# To improve performance:
# Feature Scaling
# Handle outlier
# Feature Selection
